# %%
#Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import chart_studio.plotly as py
import cufflinks as cf
import pandas as pd

cf.go_offline()
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Importar base de datos
athletes = pd.read_csv('athlete_events.csv')
poblacion = pd.read_csv('poblacion.csv')

# %%
#Explorar base de datos
athletes.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
athletes.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
athletes.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
athletes.dropna(inplace=True)

# %%
#Comparación de peso, género a través de los años. 
women_athletes = athletes[athletes.Sex == 'F']
men_athletes = athletes[athletes.Sex == 'M']

fig, ax = plt.subplots()
women_athletes_weight = women_athletes.pivot_table(index=['Year'], values=['Weight'],aggfunc=np.mean)
men_athletes_weight = men_athletes.pivot_table(index=['Year'], values=['Weight'],aggfunc=np.median)
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x=women_athletes_weight.index, y=women_athletes_weight.Weight, marker='o')
sns.lineplot(x=men_athletes_weight.index, y=men_athletes_weight.Weight,marker='o')
plt.title('Peso promedio por año',fontsize=22)
plt.xticks(men_athletes_weight.index,rotation=90)
plt.ylabel('Kg')
plt.xlabel('Año')
plt.show()

# %%
#Comparación de altura, género a través de los años. 
women_athletes = athletes[athletes.Sex == 'F']
men_athletes = athletes[athletes.Sex == 'M']

fig, ax = plt.subplots()
women_athletes_height = women_athletes.pivot_table(index=['Year'], values=['Height'],aggfunc=np.mean)
men_athletes_height = men_athletes.pivot_table(index=['Year'], values=['Height'],aggfunc=np.median)
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x=women_athletes_height.index, y=women_athletes_height.Height, marker='o',color='slateblue')
sns.lineplot(x=men_athletes_height.index, y=men_athletes_height.Height,marker='o',color='mediumseagreen')
plt.title('Altura promedio por año',fontsize=22)
plt.xticks(men_athletes_height.index,rotation=90)
plt.ylabel('Cm')
plt.xlabel('Año')
plt.show()

# %%
#Edades
edades = athletes.pivot_table(index=['Age'], values=['ID'],aggfunc={'ID':'count'})
edades_20 = edades[edades.index <= 20].agg(['sum'])
edades_21a29 = edades[(edades.index > 20) & (edades.index < 30)].agg(['sum'])
edades_30a39 = edades[(edades.index > 29) & (edades.index < 40)].agg(['sum'])
edades_40a49 = edades[(edades.index > 39) & (edades.index < 50)].agg(['sum'])
edades_50a59 = edades[(edades.index > 49) & (edades.index < 60)].agg(['sum'])
edades_60 = edades[edades.index > 60].agg(['sum'])

# %%
#Dona de edades
fig, ax = plt.subplots(figsize=(12, 9), subplot_kw=dict(aspect="equal"))

labels = ['<20','21-29','30-39','40-49','50-59','60<']

data = [edades_20['ID'], edades_21a29['ID'], edades_30a39['ID'], edades_40a49['ID'], edades_50a59['ID'], edades_60['ID']]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.6", fc="w", ec="k", lw=0.42)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0)


for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(labels[i], xy=(x, y), xytext=(.75*np.sign(x), 1.2*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("Edades", fontsize=22)
plt.show()

# %%
#Medallas
tipos_medallas = list(set(athletes.Medal))
tipos_medallas

medallas = athletes.groupby(["Team", "Year"])["Medal"].count().unstack()
medallas.head()

paises_medallas = athletes.groupby(["Team"])["Medal"].count().sort_values(ascending=False).head(15)
lista_paises= [pais for pais in paises_medallas.index]
lista_paises

med = medallas.loc[lista_paises]
med.loc["Resto del mundo"] = medallas.loc[medallas.index.difference(lista_paises)].sum()
med = med[::-1]

# %%
paises_colores = {
    "United States":"steelblue",
    "Soviet Union":"sandybrown",
    "Germany":"lightcoral",
    "Australia":"yellowgreen",
    "Russia":"indianred",
    "Canada":"darkorchid",
    "Great Britain":"blue",
    "Italy":"turquoise",
    'France': 'goldenrod',
    'East Germany': 'navy',
    'China':'orangered',
    'Japan':'purple',
    'Hungary': 'lightblue',
    'Sweden':'darksalmon',
    'Finland': 'pink',
    "Resto del mundo": "gainsboro"}

# %%
sns.set_style("ticks")
sns.set_context("notebook", font_scale=1.2)

# %%
colores = [paises_colores[c] for c in med.index]

plt.figure(figsize=(12,8))
med.T.plot.bar(stacked=True, color=colores, ax=plt.gca())

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1])

plt.ylabel("Número de medallas")
plt.title("Histórico de medallas por país")
sns.despine()

# %%
medals_per_type = athletes.groupby(["Team"])["Medal"].count().sort_values(ascending=False).head(15)

lista_paises_2 = [pais for pais in medals_per_type.index]
cuenta_paises_2 = [value for value in medals_per_type.values]

# %%
sns.barplot(x=lista_paises_2,y=cuenta_paises_2,palette='pastel')
plt.xticks(rotation=90)
plt.ylabel("Medallas")
plt.xlabel("Países")
plt.title("Países con mayor número de medallas ganadas",fontsize=18)
plt.show()

# %%
athletes.pivot_table(index=['Team','Medal'], values=['ID'],aggfunc={'ID':'count'})
# Out:
#                                       ID
# Team                         Medal
# Afghanistan                  Bronze    2
# Algeria                      Bronze    6
#                              Gold      5
#                              Silver    4
# Amateur Athletic Association Gold      2
# ...                                  ...
# Yugoslavia                   Silver  116
# Zambia                       Silver    1
# Zimbabwe                     Bronze    1
#                              Gold     17
#                              Silver    4
#
# [517 rows x 1 columns]

# %%
# Out:
# Team
# United States    2075
# Soviet Union      961
# Germany           508
# East Germany      368
# Russia            356
# Canada            350
# Great Britain     321
# Australia         313
# China             308
# Italy             302
# Hungary           289
# France            279
# Japan             226
# Netherlands       218
# Sweden            194
# Name: Medal, dtype: int64

# %%
mex_athletes = athletes[athletes.Team == 'Mexico']

# %%
mex_athletes[mex_athletes.Age == mex_athletes.Age.min()]
# Out:
#            ID                     Name Sex   Age  Height  Weight    Team  NOC  \
# 196533  98660  Mara Teresa Ramrez Gmez   F  14.0   171.0    62.0  Mexico  MEX
#
#               Games  Year  Season         City     Sport  \
# 196533  1968 Summer  1968  Summer  Mexico City  Swimming
#
#                                         Event   Medal
# 196533  Swimming Women's 800 metres Freestyle  Bronze

# %%
mex_athletes[mex_athletes.Age == mex_athletes.Age.max()]
# Out:
#            ID                      Name Sex   Age  Height  Weight    Team  \
# 156528  78626  Manuel Mendvil Yocupicio   M  44.0   176.0    68.0  Mexico
#
#         NOC        Games  Year  Season    City          Sport  \
# 156528  MEX  1980 Summer  1980  Summer  Moskva  Equestrianism
#
#                                             Event   Medal
# 156528  Equestrianism Mixed Three-Day Event, Team  Bronze

# %%
test = athletes.pivot_table(index=['Team','Medal'], values=['ID'],aggfunc={'ID':'count'})

# %%
test
# Out:
#                                       ID
# Team                         Medal
# Afghanistan                  Bronze    2
# Algeria                      Bronze    6
#                              Gold      5
#                              Silver    4
# Amateur Athletic Association Gold      2
# ...                                  ...
# Yugoslavia                   Silver  116
# Zambia                       Silver    1
# Zimbabwe                     Bronze    1
#                              Gold     17
#                              Silver    4
#
# [517 rows x 1 columns]

# %%
test.loc[lista_paises]
# Out:
#                         ID
# Team          Medal
# Australia     Bronze   471
#               Gold     313
#               Silver   412
# Canada        Bronze   338
#               Gold     350
#               Silver   336
# China         Bronze   266
#               Gold     308
#               Silver   323
# East Germany  Bronze   261
#               Gold     368
#               Silver   306
# Finland       Bronze   336
#               Gold     178
#               Silver   209
# France        Bronze   366
#               Gold     279
#               Silver   320
# Germany       Bronze   540
#               Gold     508
#               Silver   470
# Great Britain Bronze   346
#               Gold     321
#               Silver   343
# Hungary       Bronze   272
#               Gold     289
#               Silver   228
# Italy         Bronze   366
#               Gold     302
#               Silver   340
# Japan         Bronze   345
#               Gold     226
# ...

# %%
test = athletes.groupby(["Team", "Medal"])["Medal"].count()

# %%
test.
# Out:
# Team                          Medal
# Afghanistan                   Bronze      2
# Algeria                       Bronze      6
#                               Gold        5
#                               Silver      4
# Amateur Athletic Association  Gold        2
#                                        ...
# Yugoslavia                    Silver    116
# Zambia                        Silver      1
# Zimbabwe                      Bronze      1
#                               Gold       17
#                               Silver      4
# Name: Medal, Length: 517, dtype: int64

# %%
test = athletes.pivot_table(index=['Team'], columns=['Medal'],values=['ID'],aggfunc={'ID':'count'})

# %%
test.loc[lista_paises].plot(kind='bar')

# %%
test.loc[lista_paises]
# Out:
#                   ID
# Medal         Bronze    Gold  Silver
# Team
# United States  938.0  2075.0  1260.0
# Soviet Union   613.0   961.0   629.0
# Germany        540.0   508.0   470.0
# Australia      471.0   313.0   412.0
# Russia         392.0   356.0   343.0
# Canada         338.0   350.0   336.0
# Great Britain  346.0   321.0   343.0
# Italy          366.0   302.0   340.0
# France         366.0   279.0   320.0
# East Germany   261.0   368.0   306.0
# China          266.0   308.0   323.0
# Japan          345.0   226.0   270.0
# Hungary        272.0   289.0   228.0
# Sweden         270.0   194.0   291.0
# Finland        336.0   178.0   209.0

# %%
top_paises = pd.DataFrame(test.loc[lista_paises])
top_paises.reset_index(inplace=True)
top_paises.head()
top_paises.columns = top_paises.columns.droplevel(0)
top_paises = top_paises.reset_index()
top_paises.columns = ['Index','Country',
                     'Bronze','Gold','Silver']
top_paises
# Out:
#     Index        Country  Bronze    Gold  Silver
# 0       0  United States   938.0  2075.0  1260.0
# 1       1   Soviet Union   613.0   961.0   629.0
# 2       2        Germany   540.0   508.0   470.0
# 3       3      Australia   471.0   313.0   412.0
# 4       4         Russia   392.0   356.0   343.0
# 5       5         Canada   338.0   350.0   336.0
# 6       6  Great Britain   346.0   321.0   343.0
# 7       7          Italy   366.0   302.0   340.0
# 8       8         France   366.0   279.0   320.0
# 9       9   East Germany   261.0   368.0   306.0
# 10     10          China   266.0   308.0   323.0
# 11     11          Japan   345.0   226.0   270.0
# 12     12        Hungary   272.0   289.0   228.0
# 13     13         Sweden   270.0   194.0   291.0
# 14     14        Finland   336.0   178.0   209.0

# %%
bronzes = top_paises['Bronze']
silvers = top_paises['Silver']
golds = top_paises['Gold']
ind = top_paises['Country']
 
plt.bar(ind, golds, width=0.6, label='Oro', color='gold', bottom=silvers+bronzes)
plt.bar(ind, silvers, width=0.6, label='Plata', color='silver', bottom=bronzes)
plt.bar(ind, bronzes, width=0.6, label='Bronce', color='#CD7F32')
 
plt.xticks(ind)
plt.xticks(rotation=90)
plt.ylabel("Medallas")
plt.xlabel("Países")
plt.legend(loc="upper right")
plt.title("Países con mayor número de medallas ganadas",fontsize=18)
plt.show()

# %%
print(plt.style.available)
# Out:
# ['_classic_test', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10']

# %%
top_athletes = athletes.groupby(["Name"])["Medal"].count().sort_values(ascending=False).head(10)
lista_atletas = [atleta for atleta in top_athletes.index]
top_athletes.loc[lista_atletas]
# Out:
# Name
# Michael Fred Phelps, II                            28
# Larysa Semenivna Latynina (Diriy-)                 18
# Nikolay Yefimovich Andrianov                       15
# Borys Anfiyanovych Shakhlin                        13
# Ole Einar Bjrndalen                                13
# Takashi Ono                                        13
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)    12
# Ryan Steven Lochte                                 12
# Sawao Kato                                         12
# Aleksey Yuryevich Nemov                            12
# Name: Medal, dtype: int64

# %%
top_athletes = athletes.pivot_table(index=['Name'], columns=['Medal'],values=['ID'],aggfunc={'ID':'count'})

# %%
top_athletes.loc[lista_atletas]
# Out:
#                                                     ID
# Medal                                           Bronze  Gold Silver
# Name
# Michael Fred Phelps, II                            2.0  23.0    3.0
# Larysa Semenivna Latynina (Diriy-)                 4.0   9.0    5.0
# Nikolay Yefimovich Andrianov                       3.0   7.0    5.0
# Borys Anfiyanovych Shakhlin                        2.0   7.0    4.0
# Ole Einar Bjrndalen                                1.0   8.0    4.0
# Takashi Ono                                        4.0   5.0    4.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)    1.0   8.0    3.0
# Ryan Steven Lochte                                 3.0   6.0    3.0
# Sawao Kato                                         1.0   8.0    3.0
# Aleksey Yuryevich Nemov                            6.0   4.0    2.0

# %%
top_atletas = pd.DataFrame(top_athletes.loc[lista_atletas])
top_atletas.reset_index(inplace=True)
sns.barplot(x=top_atletas.Name,y=top_atletas.Medal,palette='pastel')
plt.xticks(rotation=90)
plt.ylabel("Medallas")
plt.xlabel("Atletas")
plt.title("Atletas con mayor número de medallas ganadas",fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-b4cca27ae22d> in <module>
#       1 top_atletas = pd.DataFrame(top_athletes.loc[lista_atletas])
#       2 top_atletas.reset_index(inplace=True)
# ----> 3 sns.barplot(x=top_atletas.Name,y=top_atletas.Medal,palette='pastel')
#       4 plt.xticks(rotation=90)
#       5 plt.ylabel("Medallas")
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Medal'

# %%
test2 = athletes.pivot_table(index=['Name'], columns=['Medal'],values=['ID'],aggfunc={'ID':'count'})

# %%
test2
# Out:
#                                       ID
# Medal                             Bronze Gold Silver
# Name
# A. Joshua "Josh" West                NaN  NaN    1.0
# Aage Birch                           NaN  NaN    1.0
# Aagje "Ada" Kok (-van der Linden)    NaN  1.0    2.0
# Aaron Brown                          1.0  NaN    NaN
# Aaron Egbele                         1.0  NaN    NaN
# ...                                  ...  ...    ...
# va Erds                              1.0  NaN    NaN
# va Rakusz                            1.0  NaN    1.0
# va Risztov                           NaN  1.0    NaN
# ver Maximiliano David Banega         NaN  1.0    NaN
# ystein Pettersen                     NaN  1.0    NaN
#
# [20732 rows x 3 columns]

# %%
test2.loc[lista_atletas]
# Out:
#                                                     ID
# Medal                                           Bronze  Gold Silver
# Name
# Michael Fred Phelps, II                            2.0  23.0    3.0
# Larysa Semenivna Latynina (Diriy-)                 4.0   9.0    5.0
# Nikolay Yefimovich Andrianov                       3.0   7.0    5.0
# Borys Anfiyanovych Shakhlin                        2.0   7.0    4.0
# Ole Einar Bjrndalen                                1.0   8.0    4.0
# Takashi Ono                                        4.0   5.0    4.0
# Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)    1.0   8.0    3.0
# Ryan Steven Lochte                                 3.0   6.0    3.0
# Sawao Kato                                         1.0   8.0    3.0
# Aleksey Yuryevich Nemov                            6.0   4.0    2.0

# %%
top_atletas = pd.DataFrame(test2.loc[lista_atletas])
top_atletas.reset_index(inplace=True)
top_atletas.head()
top_atletas.columns = top_atletas.columns.droplevel(0)
top_atletas = top_atletas.reset_index()
top_atletas.columns = ['Index','Nombre',
                     'Bronze','Gold','Silver']
top_atletas
# Out:
#    Index                                           Nombre  Bronze  Gold  \
# 0      0                          Michael Fred Phelps, II     2.0  23.0
# 1      1               Larysa Semenivna Latynina (Diriy-)     4.0   9.0
# 2      2                     Nikolay Yefimovich Andrianov     3.0   7.0
# 3      3                      Borys Anfiyanovych Shakhlin     2.0   7.0
# 4      4                              Ole Einar Bjrndalen     1.0   8.0
# 5      5                                      Takashi Ono     4.0   5.0
# 6      6  Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)     1.0   8.0
# 7      7                               Ryan Steven Lochte     3.0   6.0
# 8      8                                       Sawao Kato     1.0   8.0
# 9      9                          Aleksey Yuryevich Nemov     6.0   4.0
#
#    Silver
# 0     3.0
# 1     5.0
# 2     5.0
# 3     4.0
# 4     4.0
# 5     4.0
# 6     3.0
# 7     3.0
# 8     3.0
# 9     2.0

# %%
bronzes = top_atletas['Bronze']
silvers = top_atletas['Silver']
golds = top_atletas['Gold']
ind = top_atletas['Nombre']
 
plt.bar(ind, golds, width=0.6, label='Oro', color='gold', bottom=silvers+bronzes)
plt.bar(ind, silvers, width=0.6, label='Plata', color='silver', bottom=bronzes)
plt.bar(ind, bronzes, width=0.6, label='Bronce', color='#CD7F32')
 
plt.xticks(ind)
plt.xticks(rotation=45)
plt.ylabel("Medallas")
plt.xlabel("Atletas")
plt.legend(loc="upper right")
plt.title("Atletas con mayor número de medallas ganadas",fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-62f584827764> in <module>
#       4 ind = top_atletas['Nombre']
#       5
# ----> 6 plt.barh(ind, golds, width=0.6, label='Oro', color='gold', bottom=silvers+bronzes)
#       7 plt.barh(ind, silvers, width=0.6, label='Plata', color='silver', bottom=bronzes)
#       8 plt.barh(ind, bronzes, width=0.6, label='Bronce', color='#CD7F32')
#
# TypeError: barh() got multiple values for argument 'width'

# %%
bronzes = top_atletas['Bronze']
silvers = top_atletas['Silver']
golds = top_atletas['Gold']
ind = top_atletas['Nombre']
 
plt.barh(ind, golds, label='Oro', color='gold')
plt.barh(ind, silvers, label='Plata', color='silver')
plt.barh(ind, bronzes, label='Bronce', color='#CD7F32')
 
plt.xticks(ind)
plt.xticks(rotation=45)
plt.ylabel("Medallas")
plt.xlabel("Atletas")
plt.legend(loc="upper right")
plt.title("Atletas con mayor número de medallas ganadas",fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1549         try:
# -> 1550             ret = self.converter.convert(x, self.units, self)
#    1551         except Exception as e:
#
# /usr/local/lib/python3.7/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      51             raise ValueError(
# ---> 52                 'Missing category information for StrCategoryConverter; '
#      53                 'this might be caused by unintendedly mixing categorical and '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ...

# %%
mex_athletes
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 1173       654           Daniel Aceves Villagrn   M  19.0   158.0    52.0
# 8661      4757    Javier Ignacio Aquino Carmona   M  22.0   165.0    62.0
# 11204     6126           Mariana Avitia Martnez   F  18.0   164.0    61.0
# 14469     7789         David Roberto Brcena Ros   M  38.0   173.0    73.0
# 16448     8828            Daniel Bautista Rocha   M  23.0   170.0    68.0
# ...        ...                              ...  ..   ...     ...     ...
# 250719  125576                Fabin Vzquez Lpez   M  37.0   165.0    72.0
# 252440  126410     Nstor Vicente Vidrio Serrano   M  23.0   179.0    69.0
# 266350  133251  Jos Manuel Youshimatz Sotomayor   M  22.0   165.0    56.0
# 267591  133870            Alfonso Zamora Quiroz   M  18.0   160.0    54.0
# 267844  133999            Agustn Zaragoza Reyna   M  27.0   179.0    75.0
#
#           Team  NOC        Games  Year  Season         City          Sport  \
# ...

# %%
gender_mex = mex_athletes.pivot_table(index=['Sport'], columns=['Sex'],values=['ID'],aggfunc={'ID':'count'})

# %%
gender_mex.fillna(0,inplace=True)
gender_mex.columns = gender_mex.columns.droplevel(0)

# %%
gender_mex
# Out:
# Sex                       F     M
# 0              Archery  2.0   0.0
# 1            Athletics  2.0   9.0
# 2               Boxing  0.0  11.0
# 3              Cycling  1.0   1.0
# 4               Diving  5.0   8.0
# 5        Equestrianism  0.0   9.0
# 6              Fencing  1.0   0.0
# 7             Football  0.0  15.0
# 8    Modern Pentathlon  0.0   1.0
# 9             Swimming  1.0   1.0
# 10           Taekwondo  4.0   3.0
# 11       Weightlifting  1.0   0.0
# 12           Wrestling  0.0   1.0

# %%
# Out:
#          Sport   ID
# Sex               F     M
# 0      Archery  2.0   0.0
# 1    Athletics  2.0   9.0
# 2       Boxing  0.0  11.0
# 3      Cycling  1.0   1.0
# 4       Diving  5.0   8.0

# %%
gender_mex.columns = ['Deporte','F','M']
gender_mex
# Out:
#               Deporte    F     M
# 0             Archery  2.0   0.0
# 1           Athletics  2.0   9.0
# 2              Boxing  0.0  11.0
# 3             Cycling  1.0   1.0
# 4              Diving  5.0   8.0
# 5       Equestrianism  0.0   9.0
# 6             Fencing  1.0   0.0
# 7            Football  0.0  15.0
# 8   Modern Pentathlon  0.0   1.0
# 9            Swimming  1.0   1.0
# 10          Taekwondo  4.0   3.0
# 11      Weightlifting  1.0   0.0
# 12          Wrestling  0.0   1.0

# %%
mujeres = gender_mex['F']
hombres = gender_mex['M']
ind = gender_mex['Deporte']
 
plt.bar(ind, mujeres, width=0.6, label='Mujeres', color='salmon', bottom=hombres)
plt.bar(ind, hombres, width=0.6, label='Hombres', color='yellowgreen')
 
plt.xticks(ind)
plt.xticks(rotation=45)
plt.ylabel("Medallas")
plt.xlabel("Deporte")
plt.legend(loc="upper right")
plt.title("Atletas con mayor número de medallas ganadas",fontsize=18)
plt.show()

# %%
MX_BRA = athletes[(athletes.Team == 'Brazil') | (athletes.Team == 'Mexico')]
MX_BRA
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1173       654               Daniel Aceves Villagrn   M  19.0   158.0    52.0
# 1651       918                  Ademir Roque Kaefer   M  24.0   179.0    74.0
# 1652       918                  Ademir Roque Kaefer   M  28.0   179.0    74.0
# 1668       925  Adenzia Aparecida Ferreira da Silva   F  25.0   187.0    65.0
# 1733       966                         Daniel Adler   M  26.0   180.0    72.0
# ...        ...                                  ...  ..   ...     ...     ...
# 267709  133931             Arthur Nabarrete Zanetti   M  26.0   156.0    61.0
# 267844  133999                Agustn Zaragoza Reyna   M  27.0   179.0    75.0
# 268211  134186     Jos Elias "Z Elias" Moedim Jnior   M  19.0   178.0    75.0
# 268219  134191       Jos Marcelo "Z Maria" Ferreira   M  22.0   175.0    71.0
# 268247  134211               Jos Carlos Cracco Neto   M  22.0   170.0    69.0
#
# ...

# %%
athletes
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
athletes['Medal'].unique()
# Out:
# array(['Bronze', 'Gold', 'Silver'], dtype=object)

# %%
test3 = athletes.pivot_table(index=['Height'], values=['Medal'],aggfunc={'Medal':'count'})

# %%
test3.reset_index(inplace=True)

# %%
test3
# Out:
#     Height  Medal
# 0    136.0      5
# 1    137.0      2
# 2    138.0      1
# 3    139.0      4
# 4    140.0      6
# ..     ...    ...
# 81   217.0      4
# 82   218.0      6
# 83   219.0      1
# 84   220.0      3
# 85   223.0      4
#
# [86 rows x 2 columns]

# %%
test3['Height'].corr(test3['Medal'])
# Out:
# -0.028895229445164428

# %%
plt.scatter(x=test3['Height'], y=test3['Medal'])
plt.ylabel("Medallas")
plt.xlabel("Altura")
plt.title("Relación altura y medallas ganadas",fontsize=18)
plt.show()

# %%
gdp = pd.read_csv('gdp.csv')

# %%
gdp_2016 = gdp[['Country Name','2016']]

# %%
gdp_2016['2016'].corr(test3['Medal'])
# Out:
# -0.16053930479031778

# %%
test4 = athletes.pivot_table(index=['Team'], values=['Medal'],aggfunc={'Medal':'count'})

# %%
test4.reset_index(inplace=True)

# %%
lista_paises_gdp = [pais for pais in gdp_2016['Country Name']]

# %%
test4.loc[lista_paises_gdp]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-ab16b01febb2> in <module>
# ----> 1 test4.loc[lista_paises_gdp]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
# -> 1839                 return self._getitem_iterable(key, axis=axis)
#    1840
#    1841             # nested tuple slicing
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
# ...

# %%
dict_pais_medalla = gdp_2016.set_index('Country Name')['2016'].to_dict()

# %%
dict_pais_medalla
# Out:
# {'Aruba': 25239.60041,
#  'Afghanistan': 547.2281102000001,
#  'Angola': 3506.072885,
#  'Albania': 4124.108543,
#  'Andorra': 37224.10892,
#  'Arab World': 6202.890459,
#  'United Arab Emirates': 38141.84676,
#  'Argentina': 12790.242470000001,
#  'Armenia': 3591.829276,
#  'American Samoa': 11714.89568,
#  'Antigua and Barbuda': 15494.30547,
#  'Australia': 50019.967769999996,
#  'Austria': 45103.32981,
#  'Azerbaijan': 3880.7387310000004,
#  'Burundi': 282.1496815,
#  'Belgium': 41449.09736,
#  'Benin': 788.5491965,
#  'Burkina Faso': 583.8326203,
#  'Bangladesh': 1401.620628,
#  'Bulgaria': 7469.455637999999,
#  'Bahrain': 22619.11667,
#  'Bahamas, The': 31325.294830000003,
#  'Bosnia and Herzegovina': 4994.68314,
#  'Belarus': 5022.626643,
#  'Belize': 4904.034338,
#  'Bermuda': nan,
#  'Bolivia': 3076.6589489999997,
#  'Brazil': 8712.887044,
#  'Barbados': 15847.142719999998,
#  'Brunei Darussalam': 27157.346230000003,
#  'Bhutan': 3012.961401,
#  'Botswana': 7243.856017,
# ...

# %%
gdp_2016
country_names = [country for country in gdp_2016['Country Name']]

# %%
test4.columns=['Country Name','Medal']

# %%
gdp_and_medals = gdp_2016.merge(test4,on='Country Name',how='right')

# %%
gdp_and_medals
# Out:
#                Country Name          2016  Medal
# 0               Afghanistan    547.228110      2
# 1      United Arab Emirates  38141.846760      2
# 2                 Argentina  12790.242470    216
# 3                   Armenia   3591.829276     15
# 4                 Australia  50019.967770   1196
# ..                      ...           ...    ...
# 258  West Indies Federation           NaN      5
# 259              White Lady           NaN      3
# 260                 Widgeon           NaN      2
# 261    Winnipeg Shamrocks-1           NaN      2
# 262              Yugoslavia           NaN    321
#
# [263 rows x 3 columns]

# %%
plt.scatter(x=gdp_and_medals['2016'], y=gdp_and_medals['Medal'],hue=)
plt.ylabel("Medallas")
plt.xlabel("GDP")
plt.title("Relación GDP y medallas ganadas",fontsize=18)
plt.show()

# %%
poblacion_2016 = poblacion[['Country Name','2016']]

# %%
gdp_and_medals_poblacion = gdp_and_medals.merge(poblacion_2016,on='Country Name',how='right')

# %%
gdp_and_medals_poblacion.columns=['Country Name','GDP','Medal','Población']

# %%
plt.scatter(x=gdp_and_medals_poblacion['2016_y'], y=gdp_and_medals_poblacion['Medal'])
plt.ylabel("Medallas")
plt.xlabel("Población")
plt.title("Relación población y medallas ganadas",fontsize=18)
plt.show()

# %%
import plotly_express as px
px.scatter(px.data.gapminder(), x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="country", hover_name="country", 
           log_x = True, 
           size_max=45, range_x=[100,100000], range_y=[25,90])
# Out:
# <div>
#
#
#             <div id="bc7b3428-171b-4c22-9866-db519e96405d" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bc7b3428-171b-4c22-9866-db519e96405d")) {
#                     Plotly.newPlot(
#                         'bc7b3428-171b-4c22-9866-db519e96405d',
# ...

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
plt.scatter(x=gdp_and_medals_poblacion['GDP'], y=gdp_and_medals_poblacion['Medal'], s=(gdp_and_medals_poblacion['Población'])/1000000)
plt.ylabel("Medallas")
plt.xlabel("GDP")
plt.title("Relación GDP y medallas ganadas",fontsize=18)
plt.show()

# %%
gdp_and_medals_poblacion.dropna(inplace=True)


px.scatter(gdp_and_medals_poblacion, x=gdp_and_medals_poblacion['GDP'], y=gdp_and_medals_poblacion['Medal'], animation_group=gdp_and_medals_poblacion["Country Name"],
           size=gdp_and_medals_poblacion['Población'], color=gdp_and_medals_poblacion["Country Name"], hover_name=gdp_and_medals_poblacion["Country Name"], 
           log_x = True, 
           size_max=45, range_x=[100,100000], range_y=[2,5000])
# Out:
# <div>
#
#
#             <div id="a0b326c3-aea8-4d64-a7f0-8c250b9d1cec" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a0b326c3-aea8-4d64-a7f0-8c250b9d1cec")) {
#                     Plotly.newPlot(
#                         'a0b326c3-aea8-4d64-a7f0-8c250b9d1cec',
# ...

# %%
years = athletes[['Team','Year','Medal']]
years.columns=['Country Name','Year','Medal']

# %%
years_gdp_medals_pob = years.merge(gdp_and_medals_poblacion,on='Country Name',how='right')

# %%
years_gdp_medals_pob
# Out:
#       Country Name  Year Medal_x          GDP  Medal_y  Población
# 0          Finland  2014  Bronze  43493.41934    723.0  5495303.0
# 1          Finland  1948  Bronze  43493.41934    723.0  5495303.0
# 2          Finland  1948    Gold  43493.41934    723.0  5495303.0
# 3          Finland  1948    Gold  43493.41934    723.0  5495303.0
# 4          Finland  1948    Gold  43493.41934    723.0  5495303.0
# ...            ...   ...     ...          ...      ...        ...
# 21695   Costa Rica  2000  Bronze  11666.45661      4.0  4899345.0
# 21696   Costa Rica  1988  Silver  11666.45661      4.0  4899345.0
# 21697     Djibouti  1988  Bronze   1898.87599      1.0   929112.0
# 21698     Barbados  2000  Bronze  15847.14272      1.0   285796.0
# 21699        Tonga  1996  Silver   3966.15652      1.0   101133.0
#
# [21700 rows x 6 columns]

# %%
gdp_and_medals_pob.dropna(inplace=True)


px.scatter(gdp_and_medals_poblacion, x=gdp_and_medals_poblacion['GDP'], y=gdp_and_medals_poblacion['Medal'],animation_frame="year", animation_group=gdp_and_medals_poblacion["Country Name"],
           size=gdp_and_medals_poblacion['Población'], color=gdp_and_medals_poblacion["Country Name"], hover_name=gdp_and_medals_poblacion["Country Name"], 
           log_x = True, 
           size_max=45, range_x=[100,100000], range_y=[2,5000])
